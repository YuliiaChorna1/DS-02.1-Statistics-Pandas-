# %% [markdown]
# ## Introduction to Exploritary Data Analysis

# %% [markdown]
# ### Step 0: Imports and Reading Data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', 80)

# %%
df = pd.read_csv("coaster_db.csv")

# %% [markdown]
# ### Step 1: Data understanding
#
# - DataFrame `shape`
# - `head` and `tail`
# - `dtypes`
# - `describe`

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ### Step 2: Data Preparation
#
# - dropping irrelevant columns and rows
# - Identifying duplicated columns
# - Renaming Columns
# - Feature Creation

# %%
df.drop("Website", axis=1)
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df1 = df[['coaster_name', 
    # 'Length', 'Speed', 
    'Location', 'Status', 
    # 'Opening date', 'Type', 
    'Manufacturer', 
    # 'Height restriction', 'Model', 'Height',
    #    'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
    #    'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
    #    'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
    #    'Track layout', 'Fastrack available', 'Soft opening date.1',
    #    'Closing date', 'Opened', 'Replaced by', 'Website',
    #    'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
    #    'Single rider line available', 'Restraint Style',
    #    'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
    'year_introduced', 'latitude', 'longitude', 'Type_Main',
    'opening_date_clean', 
    # 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
    'speed_mph', 'height_value', 
    # 'height_unit', 'height_ft',
    'Inversions_clean', 'Gforce_clean']]

# %%
df1.shape
# Out:
# (1087, 13)

# %%
df1.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_value          float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
df1["opening_date_clean"] = pd.to_datetime(df1["opening_date_clean"])
# Out:
# C:\Users\yulic\AppData\Local\Temp\ipykernel_17960\3304727842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["opening_date_clean"] = pd.to_datetime(df1["opening_date_clean"])

# %%
df1.dtypes
# Out:
# coaster_name                  object
# Location                      object
# Status                        object
# Manufacturer                  object
# year_introduced                int64
# latitude                     float64
# longitude                    float64
# Type_Main                     object
# opening_date_clean    datetime64[ns]
# speed_mph                    float64
# height_value                 float64
# Inversions_clean               int64
# Gforce_clean                 float64
# dtype: object

# %%
df1.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_value', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df1 = df1.rename(columns = {'coaster_name': 'Coaster_Name', 
                            'year_introduced': 'Year_Introduced',
                            'opening_date_clean': 'Opening_Date', 
                            'speed_mph': 'Speed',
                            'height_value': 'Height', 
                            'Inversions_clean': 'Inversions', 
                            'Gforce_clean': 'Gforce'})

# %%
df1.head(3)
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
#
#     Status            Manufacturer  Year_Introduced  latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884    40.574    -73.978
# 1  Removed            Lina Beecher             1895    40.578    -73.979
# 2   Closed                     NaN             1896    41.580    -81.570
#
#   Type_Main Opening_Date  Speed  Height  Inversions  Gforce
# 0      Wood   1884-06-16    6.0    50.0           0     2.9
# 1      Wood   1895-01-01    NaN     NaN           1    12.0
# 2     Other          NaT    NaN     NaN           0     NaN

# %%
df1.isna()
# Out:
#       Coaster_Name  Location  Status  Manufacturer  Year_Introduced  latitude  \
# 0            False     False   False         False            False     False
# 1            False     False   False         False            False     False
# 2            False     False   False          True            False     False
# 3            False     False   False         False            False     False
# 4            False     False   False         False            False     False
# ...            ...       ...     ...           ...              ...       ...
# 1082         False     False    True         False            False      True
# 1083         False     False   False         False            False     False
# 1084         False     False    True         False            False      True
# 1085         False     False   False         False            False      True
# 1086         False     False   False         False            False      True
#
# ...

# %%
df1.isna().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year_Introduced      0
# latitude           275
# longitude          275
# Type_Main            0
# Opening_Date       250
# Speed              150
# Height             122
# Inversions           0
# Gforce             725
# dtype: int64

# %%
df1.loc[df1.duplicated(subset=["Coaster_Name"])].head()
# Out:
#                           Coaster_Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Manufacturer  Year_Introduced  \
# 43                                  Traver Engineering             1927
# 60                                      Fred W. Pearce             1937
# 61                                                 NaN             1938
# 167  Arrow Development (California and Florida)Dyna...             1980
# 237                                         Mack Rides             1986
#
#      latitude  longitude Type_Main Opening_Date  Speed  Height  Inversions  \
# ...

# %%
df1.query("Coaster_Name == 'Big Thunder Mountain Railroad'")
# Out:
#                       Coaster_Name Location Status  \
# 159  Big Thunder Mountain Railroad    Other    NaN
# 167  Big Thunder Mountain Railroad    Other    NaN
# 241  Big Thunder Mountain Railroad    Other    NaN
# 313  Big Thunder Mountain Railroad    Other    NaN
#
#                                           Manufacturer  Year_Introduced  \
# 159  Arrow Development (California and Florida)Dyna...             1979
# 167  Arrow Development (California and Florida)Dyna...             1980
# 241  Arrow Development (California and Florida)Dyna...             1987
# 313  Arrow Development (California and Florida)Dyna...             1992
#
#      latitude  longitude Type_Main Opening_Date  Speed  Height  Inversions  \
# 159       NaN        NaN     Steel          NaT   35.0   104.0           0
# 167       NaN        NaN     Steel          NaT   35.0   104.0           0
# 241       NaN        NaN     Steel          NaT   35.0   104.0           0
# ...

# %%
df2 = df1.loc[~df1.duplicated(subset=["Coaster_Name", "Location", "Opening_Date"])]\
.reset_index(drop=True).copy()

# %%
df2.shape
# Out:
# (990, 13)

# %% [markdown]
# ### Step 3: Feature Understanding
#
# (Univariate analysis)
#
# - Plotting Feature Distributions
#     - Histogram
#     - KDE
#     - Boxplot

# %%
df2["Year_Introduced"].value_counts().head(7)
# Out:
# Year_Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
# 2008    27
# 2004    25
# Name: count, dtype: int64

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12,8))

ax = df2["Year_Introduced"].value_counts().head(10)\
    .plot(kind="bar", title="Top 10 Years Coaster Intro")

ax.set_xlabel("Years")
ax.set_ylabel("Number of Coasters")

plt.show()

# %%
plt.figure(figsize=(12,8))
ax = df2["Speed"].plot(kind="hist", bins=20, title="Coaster Speed")
ax.set_xlabel("Speed")

plt.show()

# %%
plt.figure(figsize=(12,8))
ax = df2["Speed"].plot(kind="kde", title="Coaster Speed")
ax.set_xlabel("Speed")

plt.show()

# %%
df2["Type_Main"].value_counts()
# Out:
# Type_Main
# Steel    728
# Wood     191
# Other     71
# Name: count, dtype: int64

# %% [markdown]
# ### Step 4: Feature Relationships
#
# - Scatterplot
# - Heatmap Correlation
# - Pairplot
# - Groupby comparisons

# %%
plt.figure(figsize=(12,8))
ax = df2.plot(kind="scatter", x="Speed", y="Height", title="Coaster Speed vs. Height")
ax.set_xlabel("Speed")

plt.show()

# %%
df2.query("Height > 3500")
# Out:
#                       Coaster_Name Location     Status Manufacturer  \
# 836  Smoky Mountain Alpine Coaster    Other  Operating      Wiegand
#
#      Year_Introduced  latitude  longitude Type_Main Opening_Date  Speed  \
# 836             2013   35.7934   -83.5965     Steel   2013-08-03   27.0
#
#      Height  Inversions  Gforce
# 836  3937.0           0     NaN

# %%
df2 = df2.drop([836], axis=0)

# %%
plt.figure(figsize=(12,8))
df2.plot(kind="scatter", x="Speed", y="Height", title="Coaster Speed vs. Height")
ax.set_xlabel("Speed")

plt.show()

# %%
ax = sns.scatterplot(x="Speed", y="Height", hue="Type_Main", data=df2)
ax.set_title("Coaster Speed vs. Height")
plt.show()

# %%
df2.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'latitude', 'longitude', 'Type_Main', 'Opening_Date', 'Speed', 'Height',
#        'Inversions', 'Gforce'],
#       dtype='object')

# %%
sns.pairplot(df2,
             vars=['Year_Introduced', 'Speed', 'Height', 'Inversions', 'Gforce'],
             hue='Type_Main')

# %%
df2_corr = df2[['Year_Introduced', 'Speed', 'Height', 'Inversions', 'Gforce']].dropna().corr()
df2_corr
# Out:
#                  Year_Introduced     Speed    Height  Inversions    Gforce
# Year_Introduced         1.000000  0.246912  0.051000    0.130292  0.108240
# Speed                   0.246912  1.000000  0.576132    0.126254  0.511409
# Height                  0.051000  0.576132  1.000000    0.179112  0.338006
# Inversions              0.130292  0.126254  0.179112    1.000000  0.386641
# Gforce                  0.108240  0.511409  0.338006    0.386641  1.000000

# %%
sns.heatmap(df2_corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Step 5: Ask a Question about the Data
#
# - Try to answer a question you have about the data using a plot or statistic.
#
# What are the locations with the fastest roller coasters (minimum of 10)?

# %%
df2.head(3)
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
#
#     Status            Manufacturer  Year_Introduced  latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884    40.574    -73.978
# 1  Removed            Lina Beecher             1895    40.578    -73.979
# 2   Closed                     NaN             1896    41.580    -81.570
#
#   Type_Main Opening_Date  Speed  Height  Inversions  Gforce
# 0      Wood   1884-06-16    6.0    50.0           0     2.9
# 1      Wood   1895-01-01    NaN     NaN           1    12.0
# 2     Other          NaT    NaN     NaN           0     NaN

# %%
df2.query("Location != 'Other'")\
.groupby("Location")["Speed"]\
.agg(["mean", "count"])\
.query("count >= 10")\
.sort_values("mean")["mean"]\
.plot(kind="barh", figsize=(12, 6), title="Average Coaster Speed by Location")
# Out:
# <Axes: title={'center': 'Average Coaster Speed by Location'}, ylabel='Location'>
